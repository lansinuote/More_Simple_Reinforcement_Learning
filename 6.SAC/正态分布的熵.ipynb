# %%
import torch
import math

mu = torch.randn(100, 1)
sigma = torch.randn(100, 1).clamp(min=0.01)

dist = torch.distributions.Normal(mu, sigma)
entropy = dist.entropy().mean().item()

entropy
# Out:
# -1.5044562816619873

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#手动运算熵,和上面的熵等价
((2 * math.pi * math.e * sigma**2).log() * 0.5).mean().item()
# Out:
# -1.5044565200805664
